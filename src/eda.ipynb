# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
train_data = pd.read_csv("../data/train.csv")

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5352 entries, 0 to 5351
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      5352 non-null   int64
#  1   id                              5352 non-null   int64
#  2   name                            5352 non-null   object
#  3   neighborhood_overview           3476 non-null   object
#  4   host_id                         5352 non-null   int64
#  5   host_name                       5352 non-null   object
#  6   host_response_time              4263 non-null   object
#  7   host_response_rate              4263 non-null   object
#  8   host_acceptance_rate            4620 non-null   object
#  9   host_is_superhost               5315 non-null   object
#  10  host_listings_count             5352 non-null   int64
#  11  host_total_listings_count       5352 non-null   int64
# ...

# %%
train_data = train_data.drop(columns = ["Unnamed: 0", "id", "name", "host_name", 'availability_30',
 'availability_60',
 'availability_90'])

# %%
train_data.describe()
# Out:
#             host_id  host_listings_count  host_total_listings_count  \
# count  5.352000e+03          5352.000000                5352.000000
# mean   1.916746e+08            11.917601                  18.213191
# std    1.808806e+08            45.576743                  61.783016
# min    4.662000e+03             1.000000                   1.000000
# 25%    2.637491e+07             1.000000                   1.000000
# 50%    1.318506e+08             2.000000                   3.000000
# 75%    3.428838e+08             5.000000                   8.000000
# max    5.505990e+08           466.000000                1037.000000
#
#           latitude    longitude  accommodates  bathrooms  bedrooms  \
# count  5352.000000  5352.000000   5352.000000        0.0       0.0
# mean     49.262454  -123.112037      3.519619        NaN       NaN
# std       0.021200     0.037719      2.044174        NaN       NaN
# min      49.202960  -123.217730      1.000000        NaN       NaN
# ...

# %%
train_data.head()
# Out:
#                                neighborhood_overview    host_id  \
# 0  Everything you need is nearby. <br /><br />Hig...   57488206
# 1                                                NaN  139792573
# 2  Beautiful neighbourhood close to prosperous Ma...  265504225
# 3  We are located in a quiet residential neighbor...   22595056
# 4  Kitsilano at it's best! Short walk to all the ...   65683877
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0                 NaN                NaN                  NaN
# 1  within a few hours               100%                 100%
# 2      within an hour               100%                  98%
# 3                 NaN                NaN                  92%
# 4      within an hour               100%                  95%
#
#   host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                 f                    3                          3
# ...

# %%
# change columns with % strings to floats
train_data['host_response_rate'] = train_data['host_response_rate'].str.rstrip('%').astype('float') / 100.0
train_data['host_acceptance_rate'] = train_data['host_acceptance_rate'].str.rstrip('%').astype('float') / 100.0

# %%
train_data.head()
# Out:
#                                neighborhood_overview    host_id  \
# 0  Everything you need is nearby. <br /><br />Hig...   57488206
# 1                                                NaN  139792573
# 2  Beautiful neighbourhood close to prosperous Ma...  265504225
# 3  We are located in a quiet residential neighbor...   22595056
# 4  Kitsilano at it's best! Short walk to all the ...   65683877
#
#    host_response_time  host_response_rate  host_acceptance_rate  \
# 0                 NaN                 NaN                   NaN
# 1  within a few hours                 1.0                  1.00
# 2      within an hour                 1.0                  0.98
# 3                 NaN                 NaN                  0.92
# 4      within an hour                 1.0                  0.95
#
#   host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                 f                    3                          3
# ...

# %%
train_data.select_dtypes("number").columns.to_list()
# Out:
# ['host_id',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_listings_count',
#  'host_total_listings_count',
#  'latitude',
#  'longitude',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'calculated_host_listings_count',
#  'reviews_per_month',
#  'monthly_revenue']
